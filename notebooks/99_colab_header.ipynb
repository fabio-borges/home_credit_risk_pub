# %% [markdown]
# ### Colab initializations
#
# This notebook is not supposed to run on its own. For running notebooks on Colab, copy the initialization code of the following cell to the notebook.

# %%
import os
import sys

def is_on_colab():
    return 'google.colab' in sys.modules

if is_on_colab():
    os.environ['USER'] = 'fabio-borges'
    os.environ['REPO'] = 'home_credit_risk'
    os.environ['TOKEN'] = ''

    PROJECT_NAME = os.environ['REPO']
    PROJECT_DIR = f"/content/{PROJECT_NAME}"

    # !git config --global user.email "fabio.dsb@gmail.com"
    # !git config --global user.name ${USER}

    if not os.path.isdir(PROJECT_DIR):
      # %cd /content
      # !git clone https://${TOKEN}@github.com/${USER}/${REPO}.git

      # %cd {PROJECT_DIR}
      # !python3 --version
      # !pip3 install -r requirements.txt
    else:
      # %cd {PROJECT_DIR}

    DRIVE_DIR = '/content/drive/'
    if not os.path.isdir(DRIVE_DIR):
      from google.colab import drive
      drive.mount(DRIVE_DIR)

    SRC_PATH = f"{PROJECT_DIR}/src"
    if SRC_PATH not in sys.path:
      sys.path.append(SRC_PATH)

    ARTIFACTS_DIR = f"{DRIVE_DIR}/MyDrive/{PROJECT_NAME}"
    DATA_DIR = f"{ARTIFACTS_DIR}/data"
